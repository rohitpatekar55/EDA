# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#         You have been given the role of a business analyst for an E-Commerce company and have been asked to prepare a basic report on the data. Follow the steps below for preparation of the report.
#
# Before you start analysing the data, it is always a good practice to see the size of the data, its features and feature types. If the data set is big, it is not possible to print out all the records.
#     </font>
# ####  Note: Use the markdown feature of Python to explain your answer.

# %% [markdown]
# ## Load the necessary libraries. Import and load the dataset with a name ECom_Data .

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
pd.options.display.max_rows = 10

# %%
# Get the Data

ECom_Data=pd.read_csv("D:\Module 1 (Python for data science)\project/E-Commerce.csv")

# %%
df = ECom_Data

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#         We have read the data and stored the data in "ECom_Data" variable </font>

# %% [markdown]
# ## Q 1.	To get familiar with the data
# ## a)	Print out the first 10 and the last 10 records of the data. (2 marks)
# ## b)	How many rows and columns are present in the dataset? Use any two different methods to extract this information. (2 + 2 + 2 marks)
# ## c)	How many object data types are there? (1 mark)
# ## d)	Is there any Boolean data type? (1 mark)
# #### Note: Use the markdown feature of Python to explain your answer.

# %% [markdown]
# #### Ans 1 a)
# ### head() and tail() functions are  used to read first 5 and last 5 rows of the dataset

# %%
df.head(10)
# Out:
#                    Customer_uniq_id Region  Order_Date Expected_Delivery_Date  \
# 0  e71017e224688489edfe856f2308806d  East   24-10-2021             25-10-2021
# 1  6286847ee2da18f587503db49511c539  East   24-10-2021             25-10-2021
# 2  0686fec9b70e5039583a38119ca0c835   West  24-10-2021             25-10-2021
# 3  ea2406dc597bee2abb6b867fa668501f   West  24-10-2021             25-10-2021
# 4  5935ed077915347dc695744df68c565c  East   03-09-2021             04-09-2021
# 5  89fcdddaad50084e395d0928a7426afe  East   03-09-2021             04-09-2021
# 6  b9b183aa18d3a721d2ac23e7184525b0  East   03-09-2021             04-09-2021
# 7  dee64864c0419bec80fbbb94d19bc40d  East   03-09-2021             04-09-2021
# 8  595f55f2c1293f07ea9ec9fa2bb39f46  East   03-09-2021             04-09-2021
# 9  547b6585272473ae006bcfbdb47b6ae0   West  26-08-2021             27-08-2021
#
#   Delivered_Date                                       product_name  \
# ...

# %%
df.tail(10)
# Out:
#                       Customer_uniq_id Region  Order_Date  \
# 8896  4db03bc4ccbe216cf151b2f2b904ba3f  East   01-12-2020
# 8897  4d4d6aeb13fa253499d0dd45a5abd87e   West  01-12-2020
# 8898  ea19e7ef703293d3f6c799ca9db4642d   West  01-12-2020
# 8899  19a53a958992fb575acffb5d41e7ef9e  East   01-12-2020
# 8900  09abab80c8dfdc6f268e0a6f05a0be11  North  01-12-2020
# 8901  90d30478255e23621e8929ed15c2f6e4  South  01-12-2020
# 8902  20a73e3f41490a73ceeba5f17658db8f   West  01-12-2020
# 8903  5c1554cd45f9d538c2c6947dbdd59c75  East   01-12-2020
# 8904  6b737a4deca1ed0e56c179e66036e994   West  01-12-2020
# 8905  a5235ac28d3d5487f54025f9d6b57433  North  01-12-2020
#
#      Expected_Delivery_Date Delivered_Date  \
# 8896             04-12-2020     04-12-2020
# 8897             04-12-2020     04-12-2020
# 8898             04-12-2020     04-12-2020
# 8899             04-12-2020     04-12-2020
# 8900             04-12-2020     04-12-2020
# 8901             04-12-2020     04-12-2020
# ...

# %% [markdown]
# #### Ans 1 b)
# ### shape function is used to check the number of rows and columns in the dataset
# ### The len() function returns the number of items in an object. when we insert axes[0] and axes[1] it gives the number of rows and columns present in the dataset

# %%
df.shape
# Out:
# (8906, 17)

# %%
rows = len(df.axes[0])
columns = len(df.axes[1])
print('No of rows:',rows)
print('No of columns:',columns)
# Out:
# No of rows: 8906
# No of columns: 17

# %% [markdown]
# #### Ans  1 c)
# ### dtypes function describes the aspects of the data for example.
# ### type of the data (integer, float, Python object, etc.)
# ### value_counts() function returns object containing counts of unique values.
# ### by combing these two functions we get number of data types present in the dataset.

# %%
df.dtypes.value_counts()
# Out:
# object     14
# int64       2
# float64     1
# dtype: int64

# %% [markdown]
# ### Total 14 object data types are present in this dataset.

# %% [markdown]
# ### Ans 1 d)
# ### The info() method prints information about the DataFrame. The information contains the number of columns, column labels, column data types, memory usage, range index, and the number of cells in each column

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8906 entries, 0 to 8905
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Customer_uniq_id            8906 non-null   object
#  1   Region                      8906 non-null   object
#  2   Order_Date                  8906 non-null   object
#  3   Expected_Delivery_Date      8906 non-null   object
#  4   Delivered_Date              8906 non-null   object
#  5   product_name                8906 non-null   object
#  6   product_main_category       8906 non-null   object
#  7   product_subcategory         8906 non-null   object
#  8   product_category_filter     8906 non-null   object
#  9   product_category_subfilter  8906 non-null   object
#  10  product_unique ID           8906 non-null   object
#  11  retail_price                8906 non-null   int64
#  12  discounted_price            8906 non-null   int64
# ...

# %% [markdown]
# ### There is no boolean datatype in this dataset.

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#  Once you are familiar with the data, you may decide that not all features are of use to you and you may want to delete the non-informative features (columns)</font>

# %% [markdown]
# ## Q 2.	Eliminating the non-informative columns.
# ## a)	Drop the columns product_specifications and description. (2 marks)
# ## b)	Which method or function is used to permanently delete the columns mentioned in part (a)? Write the code explicitly (2 marks)
# ### Note: Use the markdown feature of Python to explain your answer.

# %% [markdown]
# ### Ans 2 a)
# ###  The drop() method removes the specified row or column. By specifying the column axis ( axis='columns' ), the drop() method removes the specified column.

# %%
df.drop(['product_specifications' ,'description'],axis=1)
# Out:
#                       Customer_uniq_id Region  Order_Date  \
# 0     e71017e224688489edfe856f2308806d  East   24-10-2021
# 1     6286847ee2da18f587503db49511c539  East   24-10-2021
# 2     0686fec9b70e5039583a38119ca0c835   West  24-10-2021
# 3     ea2406dc597bee2abb6b867fa668501f   West  24-10-2021
# 4     5935ed077915347dc695744df68c565c  East   03-09-2021
# ...                                ...    ...         ...
# 8901  90d30478255e23621e8929ed15c2f6e4  South  01-12-2020
# 8902  20a73e3f41490a73ceeba5f17658db8f   West  01-12-2020
# 8903  5c1554cd45f9d538c2c6947dbdd59c75  East   01-12-2020
# 8904  6b737a4deca1ed0e56c179e66036e994   West  01-12-2020
# 8905  a5235ac28d3d5487f54025f9d6b57433  North  01-12-2020
#
#      Expected_Delivery_Date Delivered_Date  \
# 0                25-10-2021     25-10-2021
# 1                25-10-2021     25-10-2021
# 2                25-10-2021     25-10-2021
# 3                25-10-2021     25-10-2021
# 4                04-09-2021     04-09-2021
# ...

# %% [markdown]
# ### We sucessfully removed the 'product_specifications' ,'description' from dataframe. But this change is not permanent in the dataframe, let's have a look at the df dataset again.

# %%
df.head()
# Out:
#                    Customer_uniq_id Region  Order_Date Expected_Delivery_Date  \
# 0  e71017e224688489edfe856f2308806d  East   24-10-2021             25-10-2021
# 1  6286847ee2da18f587503db49511c539  East   24-10-2021             25-10-2021
# 2  0686fec9b70e5039583a38119ca0c835   West  24-10-2021             25-10-2021
# 3  ea2406dc597bee2abb6b867fa668501f   West  24-10-2021             25-10-2021
# 4  5935ed077915347dc695744df68c565c  East   03-09-2021             04-09-2021
#
#   Delivered_Date                                       product_name  \
# 0     25-10-2021  Indcrown Net Embroidered Semi-stitched Lehenga...
# 1     25-10-2021      Shopmania Music Band A5 Notebook Spiral Bound
# 2     25-10-2021      Shopmania Music Band A5 Notebook Spiral Bound
# 3     25-10-2021  Tiara Diaries 2016-2017 Designer LA Kaarta "TA...
# 4     04-09-2021                KAJCI Embroidered Women's Waistcoat
#
#   product_main_category    product_subcategory product_category_filter  \
# ...

# %% [markdown]
# ### Ans 2 b)

# %% [markdown]
# ### We see that df dataset still has 'product_specifications' ,'description' column in it.
# ### To make permanent changes to a dataframe there are two methods will have to use a parameter inplace and set its value to True. Before removing columns permanantly, it is always a good idea to store the new/updated data frames in new variables to avoid changes to the existing data frame
# ### creating a copy of the existing data frame

# %%
df1 = df.copy()

# %%
df1.drop(['product_specifications','description'], axis=1, inplace=True)

# %%
df1.head()
# Out:
#                    Customer_uniq_id Region  Order_Date Expected_Delivery_Date  \
# 0  e71017e224688489edfe856f2308806d  East   24-10-2021             25-10-2021
# 1  6286847ee2da18f587503db49511c539  East   24-10-2021             25-10-2021
# 2  0686fec9b70e5039583a38119ca0c835   West  24-10-2021             25-10-2021
# 3  ea2406dc597bee2abb6b867fa668501f   West  24-10-2021             25-10-2021
# 4  5935ed077915347dc695744df68c565c  East   03-09-2021             04-09-2021
#
#   Delivered_Date                                       product_name  \
# 0     25-10-2021  Indcrown Net Embroidered Semi-stitched Lehenga...
# 1     25-10-2021      Shopmania Music Band A5 Notebook Spiral Bound
# 2     25-10-2021      Shopmania Music Band A5 Notebook Spiral Bound
# 3     25-10-2021  Tiara Diaries 2016-2017 Designer LA Kaarta "TA...
# 4     04-09-2021                KAJCI Embroidered Women's Waistcoat
#
#   product_main_category    product_subcategory product_category_filter  \
# ...

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#         The next steps in this project involves summarization of data at various levels and visualization. Apparently, such simple steps are very useful to get an overall sense of the data.
#     </font>

# %% [markdown]
# ## Q 3. Here we summarize the data at Brand level.
# ## a) How many unique Brand are there? (2 marks)
# ## b) Note that each Brand contains multiple products. Show the average product_rating within each Brand (2 marks)

# %% [markdown]
# ### Ans 3 a)
# ### The nunique() method returns the number of unique values for each column

# %%
df1['Brand'].nunique()
# Out:
# 2484

# %% [markdown]
# ### Ans 3 b)
# ### A groupby() method involves some combination of splitting the object, applying a function, and combining the results.

# %%
df1.groupby(['Brand'])['product_rating'].mean()
# Out:
# Brand
# 1OAK           1.500000
# 3A AUTOCARE    3.268293
# 3D MAT         3.000000
# 3KFACTORY      2.000000
# 4D             3.600000
#                  ...
# ZORDEN         4.000000
# ZOSIGN         3.400000
# ZRESTHA        1.000000
# ZYXEL          3.333333
#  TARKAN        5.000000
# Name: product_rating, Length: 2484, dtype: float64

# %% [markdown]
# ## Q 4. Next we study the main categories of the products.
#
# ## a) Create an appropriate plot to show the count of items ordered for each product_main_category. (6 marks).
#
# ### Hint: Create a bar chart titled "Product Category type" where product_main_category are on x-axis and counts are on y-axis.
#
# ### Note: Both axis labels, i.e. the names of the product_main_category and counts must be clearly legible.
#
# ## b) From the plot identify for which two product_main_category(s)  maximum and minimum orders were placed. (2 marks)
#
# ## c) Write code to print out the top 5 product_main_category(s)  in descending order? (3 marks

# %% [markdown]
# ### Ans 4 a)
# ### The countplot is used to represent the occurrence(counts) of the observation present in the categorical variable. It uses the concept of a bar chart for the visual depiction.

# %%
plt.figure(figsize=(12,7))
ax = sns.countplot(data=df1,x='product_main_category')
plt.title('Product Category type')
plt.ylim(0,3500)
plt.xlabel('product_main_category')
plt.ylabel('counts')
plt.xticks(rotation=90)
plt.bar_label(ax.containers[0]);

# %% [markdown]
# ### Ans 4 b)

# %% [markdown]
# ### The maximum product_main_category order were placed is Clothing.
# ### The minimum product_main_category order were placed is Wearable Smart Devices.

# %% [markdown]
# ### Ans 4 c)
# ### value_counts() function returns object containing counts of unique values.
# ### head() function is used read first or top 5 rows of the dataset.

# %%
df1['product_main_category'].value_counts().head(5)
# Out:
# Clothing                       2943
# Mobiles & Accessories          1084
# Automotive                     1001
# Home Decor & Festive Needs      727
# Computers                       558
# Name: product_main_category, dtype: int64

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#     In E-commerce, both the retailers (here brands) and the company have to make profit to sustain in the business.
#     The E-Commerce company has the following rule for computing their own revenue: </font>
#
# ####     The company charges
# ####  (i) 25% on the orders having final price (discounted price) greater than 600
#
# #### (ii) 15% on the orders having final price (discounted price) greater than 350 but less than or equal to 600
#
# #### (iii) 10% on the orders having final price (discounted price) greater than 100 but less than or equal to 350
#
# #### (iv) Otherwise, 5% on the final price (discounted price)    </font>

# %% [markdown]
# ## Q 5. Find the Total Revenue generated by the E-Commerce company over all orders placed. (6 marks)
#
# #### Hint: Calculate revenue of E-commerce company using the conditions mentioned above and then do the total (sum) of all to get total Revenue.

# %% [markdown]
# ### Ans 5
# ### Python def keyword is used to define a function, it is placed before a function name that is provided by the user to create a user-defined function
# ### The apply() method allows you to apply a function along one of the axis of the DataFrame, default 0, which is the index (row) axis.

# %%
def calculate_revenue(x):
    
    if x > 600:
        return x*0.25
    elif x > 350:
        return x*0.15
    elif x > 100:
        return x*0.10
    else:
        return x*0.05
# creating a new column'Revenue' by using apply function to discounted_price
df1['Revenue'] = df1['discounted_price'].apply(calculate_revenue)
df1.head()
# Out:
#                    Customer_uniq_id Region  Order_Date Expected_Delivery_Date  \
# 0  e71017e224688489edfe856f2308806d  East   24-10-2021             25-10-2021
# 1  6286847ee2da18f587503db49511c539  East   24-10-2021             25-10-2021
# 2  0686fec9b70e5039583a38119ca0c835   West  24-10-2021             25-10-2021
# 3  ea2406dc597bee2abb6b867fa668501f   West  24-10-2021             25-10-2021
# 4  5935ed077915347dc695744df68c565c  East   03-09-2021             04-09-2021
#
#   Delivered_Date                                       product_name  \
# 0     25-10-2021  Indcrown Net Embroidered Semi-stitched Lehenga...
# 1     25-10-2021      Shopmania Music Band A5 Notebook Spiral Bound
# 2     25-10-2021      Shopmania Music Band A5 Notebook Spiral Bound
# 3     25-10-2021  Tiara Diaries 2016-2017 Designer LA Kaarta "TA...
# 4     04-09-2021                KAJCI Embroidered Women's Waistcoat
#
#   product_main_category    product_subcategory product_category_filter  \
# ...

# %%
#calculate the total revenue by using sum() function.
total_revenue = df1['Revenue'].sum()
print('The total Revenue generated by the E-Commerce company over all orders placed is',total_revenue,'Rupees')
# Out:
# The total Revenue generated by the E-Commerce company over all orders placed is 2217486.85 Rupees

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#     Now you need to find the revenue for each retailer (Brand)
#     </font>

# %% [markdown]
# ## Q6.Calculate the total BrandRevenue and list the top 10 Brand having maximum revenue in descending order (6 marks)
# #### Hint: Total BrandRevenue is BrandRevenue which is generated after all the deductions. Also, BrandRevenue is different from the E-Commerce company's revenue.
# #### Brand Revenue is the discounted price minus the Revenue (generated using the conditions given above Q5)

# %% [markdown]
# ### Ans 6

# %%
#create a new column 'total_brand_revenue' by subtracting Revenue from discounted_price
df1['total_brand_revenue']= df1['discounted_price']-df1['Revenue'] 
df1.groupby(['Brand'])['total_brand_revenue'].sum().sort_values(ascending = False).head(10)
# Out:
# Brand
# ALLURE AUTO     498464.25
# GAGA            237390.00
# SLIM            212062.60
# DAILYOBJECTS    181980.00
# DIVINITI        143115.00
# THELOSTPUPPY    127287.50
# REGULAR         126536.50
# ENTHOPIA        123146.25
# ASUS             99241.50
# SPRINGWEL        88978.50
# Name: total_brand_revenue, dtype: float64

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
# Let us now investigate multiple features for each product to determine any pattern.
# </font>

# %% [markdown]
# ## Q 7. Compare prices for each product.
#
# ## a)	Draw boxplots of retail_price & discounted_price. (3 marks)
#
# ## b)	 Are there any outliers? (Yes/No) (1mark)
#
# ## c)	Create a scatterplot of retail_price (x-axis) and discounted_price (y-axis) (3 marks)

# %% [markdown]
# ### Ans 7 a)
# ### Boxplots are a measure of how well distributed the data in a data set

# %%
plt.figure(figsize =(10,5))
plt.title('Boxplot: Retail_Price')
plt.xlabel('retail_price')
sns.axes_style('whitegrid')
sns.boxplot(data=df1,x='retail_price',color='orange');

# %%
plt.figure(figsize =(10,5))
plt.title('Boxplot: Discounted_Price')
plt.xlabel('discounted_price')
sns.axes_style('whitegrid')
sns.boxplot(data=df1,x='discounted_price',color='blue');

# %% [markdown]
# ### Ans 7 b)

# %% [markdown]
# ### Yes, both boxplots are positively skewed and has outliers in it

# %% [markdown]
# ### Ans 7 c)
# ### A scatter plot is a visual representation of how two variables relate to each other. You can use scatter plots to explore the relationship between two variables.

# %%
sns.scatterplot(data=df1,x='retail_price',y='discounted_price',color='green');

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#     The next steps will enable to study brand-level information.
#     </font>

# %% [markdown]
# ## Q 8. Create a new dataframe to include the Brand specific information as stated:
# ## i.	total number of orders placed per Brand
# ## ii.	total retail_price per Brand
# ## iii.	total discounted_price per Brand, and
# ## iv.	total BrandRevenue generated per Brand.
#
# ## Also, draw a pairplot using these four features. (6 marks)

# %% [markdown]
# ### Ans 8

# %%
#Calculate total number of orders placed per Brand.
total_orders=df1['Brand'].value_counts()
print(total_orders)
# Out:
# ALLURE AUTO       469
# REGULAR           300
# SLIM              267
# THELOSTPUPPY      250
# BLACK             147
#                  ...
# WRITEFLO            1
# JAZAM               1
# RADIUS              1
# I-STATIC            1
# AMBIKA LAHENGA      1
# Name: Brand, Length: 2484, dtype: int64

# %%
#Calculate total retail_price per Brand.
total_retail_price = df1.groupby(['Brand'])['retail_price'].sum()
print(total_retail_price)
# Out:
# Brand
# 1OAK             1698
# 3A AUTOCARE    107059
# 3D MAT           7250
# 3KFACTORY         399
# 4D              17500
#                 ...
# ZORDEN           3999
# ZOSIGN           6995
# ZRESTHA          1999
# ZYXEL           64742
#  TARKAN          1999
# Name: retail_price, Length: 2484, dtype: int64

# %%
#Calculate total discounted_price per Brand.
total_discounted_price = df1.groupby(['Brand'])['discounted_price'].sum()
print(total_discounted_price)
# Out:
# Brand
# 1OAK            1274
# 3A AUTOCARE    74134
# 3D MAT          6999
# 3KFACTORY        174
# 4D              7948
#                ...
# ZORDEN          2799
# ZOSIGN          6995
# ZRESTHA          899
# ZYXEL          35392
#  TARKAN          349
# Name: discounted_price, Length: 2484, dtype: int64

# %%
#Calculate total BrandRevenue generated per Brand.
total_BrandRevenue_generated = df1.groupby(['Brand'])['total_brand_revenue'].sum()
print(total_BrandRevenue_generated)
# Out:
# Brand
# 1OAK            1015.40
# 3A AUTOCARE    55647.90
# 3D MAT          5249.25
# 3KFACTORY        156.60
# 4D              5961.00
#                  ...
# ZORDEN          2099.25
# ZOSIGN          5246.25
# ZRESTHA          674.25
# ZYXEL          26544.00
#  TARKAN          314.10
# Name: total_brand_revenue, Length: 2484, dtype: float64

# %%
#creating a new DataFrame
df2=pd.DataFrame(columns=['total_retail_price','total_orders','total_discounted_price', 'total_BrandRevenue_generated'])
df2['total_retail_price']=total_retail_price
df2['total_orders']=total_orders
df2['total_discounted_price']=total_discounted_price
df2['total_BrandRevenue_generated']=total_BrandRevenue_generated
df2
# Out:
#              total_retail_price  total_orders  total_discounted_price  \
# Brand
# 1OAK                       1698             2                    1274
# 3A AUTOCARE              107059            41                   74134
# 3D MAT                     7250             1                    6999
# 3KFACTORY                   399             1                     174
# 4D                        17500             5                    7948
# ...                         ...           ...                     ...
# ZORDEN                     3999             1                    2799
# ZOSIGN                     6995             5                    6995
# ZRESTHA                    1999             1                     899
# ZYXEL                     64742             9                   35392
#  TARKAN                    1999             1                     349
#
#              total_BrandRevenue_generated
# Brand
# 1OAK                              1015.40
# ...

# %%
plt.figure(figsize=(20,12))
sns.pairplot(data=df2[['total_BrandRevenue_generated','total_retail_price','total_discounted_price','total_orders']]);

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#     The E-Commerce company operate in multiple regions. It is important to understand its performance in each region.
#     </font>

# %% [markdown]
# ## Q 9.Compare performance regionwise
#
# ## a)	Draw a lineplot for the monthly Revenue of E-Commerce Company for each region separately.  (4 marks)
#
# ## b)	Identify the best and the worst performing months for each region. (2 marks)
#
# #### Note: Only those days with actual orders(Order_Date) placed are present in the dataset. Assuming there were no orders on other days. Also, show Month and Year on x-axis.

# %% [markdown]
# ### Ans 9 a)

# %%
df1['Order_Date']  = pd.to_datetime(df1['Order_Date'],dayfirst=True)

# %%
# strftime() is a Python date method you can use to convert dates to strings. 
# It doesn't just convert to strings, but also allows you to format your dates in a readable way.
df1['Order_Date'].dt.strftime('%d-%m-%y')
# Out:
# 0       24-10-21
# 1       24-10-21
# 2       24-10-21
# 3       24-10-21
# 4       03-09-21
#           ...
# 8901    01-12-20
# 8902    01-12-20
# 8903    01-12-20
# 8904    01-12-20
# 8905    01-12-20
# Name: Order_Date, Length: 8906, dtype: object

# %%
# creating a new column 'months' and adding the extracted month values into the dataframe
df1['months'] = df1['Order_Date'].dt.month

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
plt.figure(figsize = (16,8))
plt.xticks(np.arange(0,13,1))
sns.lineplot(data=df1,x = 'months' , y = 'Revenue', ci = False ,hue='Region');
warnings.resetwarnings()

# %% [markdown]
# ### Ans 9 b)

# %% [markdown]
# ### The North region excelled in performance during August ,  but it generated the lowest revenue in the month of July.
# ### The East region excelled in performance during August ,  but it generated the lowest revenue in the month of October.
# ### The West region excelled in performance during March ,  but it generated the lowest revenue in the month of October.
# ### The South region excelled in performance during March ,  but it generated the lowest revenue in the month of May.

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#     Congratulations! You have learnt how to approach a complex data and extract information out of it.
#     </font>
